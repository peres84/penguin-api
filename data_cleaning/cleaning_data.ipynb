# %%
#importing libraries
import pandas as pd

# %%
#dataset
df= pd.read_csv("../data/penguins_lter.csv")

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
df.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
df = df.drop(columns=['studyName', 'Sample Number', 'Stage',
       'Individual ID', 'Clutch Completion', 'Date Egg', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'])

# %%
df
# Out:
#                                  Species  Region     Island  \
# 0    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                   ...     ...        ...
# 339    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
#
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0                  39.1               18.7                181.0
# 1                  39.5               17.4                186.0
# ...

# %%
df.shape
# Out:
# (344, 8)

# %%
df.columns
# Out:
# Index(['Species', 'Region', 'Island', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex'],
#       dtype='object')

# %%
df = df.drop_duplicates(subset=['Species', 'Region', 'Island', 'Culmen Length (mm)',
       'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex'])

# %%
df.shape
# Out:
# (344, 8)

# %%
df.isna().sum()
# Out:
# Species                 0
# Region                  0
# Island                  0
# Culmen Length (mm)      2
# Culmen Depth (mm)       2
# Flipper Length (mm)     2
# Body Mass (g)           2
# Sex                    10
# dtype: int64

# %%
df["Species"][0].split()
# Out:
# ['Adelie', 'Penguin', '(Pygoscelis', 'adeliae)']

# %%
def name_format(string):
    string = string.split(sep = " ")
    string = string[0] + " " + string[1] 
    return string

# %%
df["Species_format"] = df["Species"].apply(name_format)
df["Species"] = df["Species_format"]

# %%
df = df.drop(columns='Species_format')

# %%
df["Region"][0]
# Out:
# 'Anvers'

# %%
df["Culmen Length (mm)"][0]
# Out:
# 39.1

# %%
type(df["Culmen Length (mm)"][0])
# Out:
# numpy.float64

# %%
df["Sex"][0]
# Out:
# 'MALE'

# %%
df
# Out:
#             Species  Region     Island  Culmen Length (mm)  Culmen Depth (mm)  \
# 0    Adelie Penguin  Anvers  Torgersen                39.1               18.7
# 1    Adelie Penguin  Anvers  Torgersen                39.5               17.4
# 2    Adelie Penguin  Anvers  Torgersen                40.3               18.0
# 3    Adelie Penguin  Anvers  Torgersen                 NaN                NaN
# 4    Adelie Penguin  Anvers  Torgersen                36.7               19.3
# ..              ...     ...        ...                 ...                ...
# 339  Gentoo penguin  Anvers     Biscoe                 NaN                NaN
# 340  Gentoo penguin  Anvers     Biscoe                46.8               14.3
# 341  Gentoo penguin  Anvers     Biscoe                50.4               15.7
# 342  Gentoo penguin  Anvers     Biscoe                45.2               14.8
# 343  Gentoo penguin  Anvers     Biscoe                49.9               16.1
#
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#             Species  Region     Island  Culmen Length (mm)  Culmen Depth (mm)  \
# 0    Adelie Penguin  Anvers  Torgersen                39.1               18.7
# 1    Adelie Penguin  Anvers  Torgersen                39.5               17.4
# 2    Adelie Penguin  Anvers  Torgersen                40.3               18.0
# 4    Adelie Penguin  Anvers  Torgersen                36.7               19.3
# 5    Adelie Penguin  Anvers  Torgersen                39.3               20.6
# ..              ...     ...        ...                 ...                ...
# 338  Gentoo penguin  Anvers     Biscoe                47.2               13.7
# 340  Gentoo penguin  Anvers     Biscoe                46.8               14.3
# 341  Gentoo penguin  Anvers     Biscoe                50.4               15.7
# 342  Gentoo penguin  Anvers     Biscoe                45.2               14.8
# 343  Gentoo penguin  Anvers     Biscoe                49.9               16.1
#
# ...

# %%
df.isna().sum()
# Out:
# Species                0
# Region                 0
# Island                 0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Sex                    0
# dtype: int64

# %%
df.dtypes
# Out:
# Species                 object
# Region                  object
# Island                  object
# Culmen Length (mm)     float64
# Culmen Depth (mm)      float64
# Flipper Length (mm)    float64
# Body Mass (g)          float64
# Sex                     object
# dtype: object

# %%
df.describe()
# Out:
#        Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# count          334.000000         334.000000           334.000000
# mean            43.994311          17.160479           201.014970
# std              5.460521           1.967909            14.022175
# min             32.100000          13.100000           172.000000
# 25%             39.500000          15.600000           190.000000
# 50%             44.500000          17.300000           197.000000
# 75%             48.575000          18.700000           213.000000
# max             59.600000          21.500000           231.000000
#
#        Body Mass (g)
# count     334.000000
# mean     4209.056886
# std       804.836129
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4793.750000
# max      6300.000000
